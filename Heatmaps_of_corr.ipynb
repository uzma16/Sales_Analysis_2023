# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_excel('data.xlsx')

# %%
# Taking out month from the Date & adding as a new column

data['Month'] = pd.to_datetime(data['Invoice Date']).dt.month

# %%
# Finding Correlation 

data.corr()
# Out:
#              Invoice ID  Customer ID     Total  Quantity  Item Total  \
# Invoice ID     1.000000     0.121010  0.029860 -0.005948    0.010983
# Customer ID    0.121010     1.000000 -0.013421  0.027716    0.027274
# Total          0.029860    -0.013421  1.000000  0.323371    0.422263
# Quantity      -0.005948     0.027716  0.323371  1.000000    0.748336
# Item Total     0.010983     0.027274  0.422263  0.748336    1.000000
# Item Price     0.099288     0.001729  0.027896 -0.148505    0.039536
# Product ID    -0.081741     0.013490  0.015552 -0.001798    0.008360
# Month          0.974018     0.120766  0.035627 -0.004816    0.013038
#
#              Item Price  Product ID     Month
# Invoice ID     0.099288   -0.081741  0.974018
# Customer ID    0.001729    0.013490  0.120766
# Total          0.027896    0.015552  0.035627
# Quantity      -0.148505   -0.001798 -0.004816
# Item Total     0.039536    0.008360  0.013038
# Item Price     1.000000    0.046273  0.100411
# Product ID     0.046273    1.000000 -0.077771
# Month          0.100411   -0.077771  1.000000

# %%
#Correlation plot

sns.heatmap(data.corr(),cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>
